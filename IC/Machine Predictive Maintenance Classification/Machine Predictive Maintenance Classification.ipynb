# %% [markdown]
# **Conjunto de dados de classificação de manutenção preditiva da máquina**  é um conjunto de dados de sensores coletados em uma fábrica de produção de aço. O objetivo do conjunto de dados é prever se uma determinada máquina irá ou não falhar em um futuro próximo, com base em dados de sensores coletados.
# https://www.kaggle.com/datasets/shivamb/machine-predictive-maintenance-classification

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\IC\Machine Predictive Maintenance Classification\predictive_maintenance.csv",header=None)

# %%
data
# Out:
#            0           1     2                    3                        4  \
# 0        UDI  Product ID  Type  Air temperature [K]  Process temperature [K]
# 1          1      M14860     M                298.1                    308.6
# 2          2      L47181     L                298.2                    308.7
# 3          3      L47182     L                298.1                    308.5
# 4          4      L47183     L                298.2                    308.6
# ...      ...         ...   ...                  ...                      ...
# 9996    9996      M24855     M                298.8                    308.4
# 9997    9997      H39410     H                298.9                    308.4
# 9998    9998      M24857     M                  299                    308.6
# 9999    9999      H39412     H                  299                    308.7
# 10000  10000      M24859     M                  299                    308.7
#
# ...
